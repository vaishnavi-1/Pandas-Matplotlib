# %% [markdown]
# ## Functions and methods

# %% [markdown]
# ### Dataframe/ Series.head() function

# %%
import pandas as pd
data = pd.read_csv("COVID19_line_list_data.csv")
d = data.head()
d
# Out:
#    id  case_in_country reporting date  Unnamed: 3  \
# 0   1              NaN      1/20/2020         NaN
# 1   2              NaN      1/20/2020         NaN
# 2   3              NaN      1/21/2020         NaN
# 3   4              NaN      1/21/2020         NaN
# 4   5              NaN      1/21/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3  new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4  new confirmed imported COVID-19 pneumonia in T...              Tianjin
#
#   country  gender   age symptom_onset  ...  recovered symptom  \
# 0   China    male  66.0      01/03/20  ...          0     NaN
# 1   China  female  56.0     1/15/2020  ...          0     NaN
# ...

# %%
# Setting n value in .head() function

import pandas as pd
data = pd.read_csv("COVID19_line_list_data.csv")
df = data["location"]
d = df.head(9)
d
# Out:
# 0    Shenzhen, Guangdong
# 1               Shanghai
# 2               Zhejiang
# 3                Tianjin
# 4                Tianjin
# 5              Chongqing
# 6                Sichuan
# 7                Beijing
# 8                Beijing
# Name: location, dtype: object

# %% [markdown]
# ### Dataframe/ Series.describe() function

# %%
# importing pandas module  
import pandas as pd  
  
# importing regex module 
import re 
    
# making data frame  
data = pd.read_csv("COVID19_line_list_data.csv")  
    
# removing null values to avoid errors  
data.dropna(inplace = True)  
  
# percentile list 
perc =[.30, .50, .70, .90] 
  
# list of dtypes to include 
include =['object', 'float', 'int'] 
  
# calling describe method 
desc = data.describe(percentiles = perc, include = include) 
  
# display 
desc
# Out:
#         case_in_country reporting date  Unnamed: 3 summary location country  \
# count               0.0              0         0.0       0        0       0
# unique              NaN              0         NaN       0        0       0
# top                 NaN            NaN         NaN     NaN      NaN     NaN
# freq                NaN            NaN         NaN     NaN      NaN     NaN
# mean                NaN            NaN         NaN     NaN      NaN     NaN
# std                 NaN            NaN         NaN     NaN      NaN     NaN
# min                 NaN            NaN         NaN     NaN      NaN     NaN
# 30%                 NaN            NaN         NaN     NaN      NaN     NaN
# 50%                 NaN            NaN         NaN     NaN      NaN     NaN
# 70%                 NaN            NaN         NaN     NaN      NaN     NaN
# 90%                 NaN            NaN         NaN     NaN      NaN     NaN
# ...

# %% [markdown]
# ### Dataframe/Series.loc() method

# %%
import pandas as pd
data = pd.read_csv("COVID19_line_list_data.csv", index_col ="location")
first = data.loc["Beijing"]
second = data.loc["Shanghai"]

print(first, "\n\n\n", second)
# Out:
#            id  case_in_country reporting date  Unnamed: 3  \
# location
# Beijing     8              NaN      1/21/2020         NaN
# Beijing     9              NaN      1/21/2020         NaN
# Beijing    10              NaN      1/21/2020         NaN
# Beijing    11              NaN      1/21/2020         NaN
# Beijing    12              NaN      1/21/2020         NaN
# Beijing    36              NaN      1/22/2020         NaN
# Beijing    37              NaN      1/22/2020         NaN
# Beijing    38              NaN      1/22/2020         NaN
# Beijing    39              NaN      1/22/2020         NaN
# Beijing    92              NaN      1/24/2020         NaN
# Beijing   117              NaN      1/25/2020         NaN
# Beijing   146              NaN      1/21/2020         NaN
# Beijing   147              NaN      1/21/2020         NaN
# Beijing   148              NaN      1/25/2020         NaN
# Beijing   170              NaN      1/27/2020         NaN
# ...

# %% [markdown]
# ### Dataframe/Series.iloc[] method

# %%
# importing pandas package 
import pandas as pd 
  
# making data frame from csv file  
data = pd.read_csv("COVID19_line_list_data.csv") 
  
# retrieving rows by loc method  
row1 = data.loc[2]
  
# retrieving rows by iloc method 
row2 = data.iloc[2] 
# checking if values are equal 
row1 == row2
# Out:
# id                        True
# case_in_country          False
# reporting date            True
# Unnamed: 3               False
# summary                   True
# location                  True
# country                   True
# gender                    True
# age                       True
# symptom_onset             True
# If_onset_approximated     True
# hosp_visit_date           True
# exposure_start           False
# exposure_end              True
# visiting Wuhan            True
# from Wuhan                True
# death                     True
# recovered                 True
# symptom                  False
# source                    True
# link                      True
# Unnamed: 21              False
# Unnamed: 22              False
# Unnamed: 23              False
# Unnamed: 24              False
# Unnamed: 25              False
# Unnamed: 26              False
# Name: 2, dtype: bool

# %%
# importing pandas package 
import pandas as pd 
  
# making data frame from csv file  
data = pd.read_csv("COVID19_line_list_data.csv") 
  
# retrieving rows by loc method  
row1 = data.iloc[[14, 15, 16, 17]] 
  
# retrieving rows by loc method  
row2 = data.iloc[14:18] 
  
# comparing values
row1 == row2
# Out:
#       id  case_in_country  reporting date  Unnamed: 3  summary  location  \
# 14  True            False            True       False     True      True
# 15  True            False            True       False     True      True
# 16  True            False            True       False     True      True
# 17  True            False            True       False     True      True
#
#     country  gender   age  symptom_onset  ...  recovered  symptom  source  \
# 14     True    True  True           True  ...       True    False    True
# 15     True    True  True           True  ...       True    False    True
# 16     True    True  True           True  ...       True    False    True
# 17     True    True  True           True  ...       True    False    True
#
#     link  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25  \
# 14  True        False        False        False        False        False
# 15  True        False        False        False        False        False
# ...

# %% [markdown]
# ### Pandas.read_csv() method

# %%
#Import pandas
import pandas as pd

#reading a csv file
pd.read_csv("COVID19_line_list_data.csv")
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# ...

# %%
#Example 2
# importing Pandas library 
import pandas as pd 
  
pd.read_csv(filepath_or_buffer = "COVID19_line_list_data.csv")
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# ...

# %%
# makes the passed rows header 
pd.read_csv( "COVID19_line_list_data.csv",header =[11, 12])
# Out:
#         11 Unnamed: 1_level_0  1/21/2020 Unnamed: 3_level_0  \
#         12 Unnamed: 1_level_1  1/21/2020 Unnamed: 3_level_1
# 0       13                NaN  1/21/2020                NaN
# 1       14                NaN  1/21/2020                NaN
# 2       15                NaN  1/22/2020                NaN
# 3       16                NaN  1/22/2020                NaN
# 4       17                NaN  1/22/2020                NaN
# ...    ...                ...        ...                ...
# 1068  1081                2.0  2/25/2020                NaN
# 1069  1082                1.0  2/24/2020                NaN
# 1070  1083                1.0  2/26/2020                NaN
# 1071  1084                1.0  2/25/2020                NaN
# 1072  1085                1.0  2/25/2020                NaN
#
# ...

# %%
# make the passed column as index instead of 0, 1, 2, 3.... 
pd.read_csv("COVID19_line_list_data.csv", index_col ='country')
# Out:
#                id  case_in_country reporting date  Unnamed: 3  \
# country
# China           1              NaN      1/20/2020         NaN
# China           2              NaN      1/20/2020         NaN
# China           3              NaN      1/21/2020         NaN
# China           4              NaN      1/21/2020         NaN
# China           5              NaN      1/21/2020         NaN
# ...           ...              ...            ...         ...
# Austria      1081              2.0      2/25/2020         NaN
# Afghanistan  1082              1.0      2/24/2020         NaN
# Algeria      1083              1.0      2/26/2020         NaN
# Croatia      1084              1.0      2/25/2020         NaN
# Switzerland  1085              1.0      2/25/2020         NaN
#
#                                                        summary  \
# country
# China        First confirmed imported COVID-19 pneumonia pa...
# China        First confirmed imported COVID-19 pneumonia pa...
# ...

# %%
# uses passed cols only for data frame 
pd.read_csv("COVID19_line_list_data.csv", usecols =["country"])
# Out:
#           country
# 0           China
# 1           China
# 2           China
# 3           China
# 4           China
# ...           ...
# 1080      Austria
# 1081  Afghanistan
# 1082      Algeria
# 1083      Croatia
# 1084  Switzerland
#
# [1085 rows x 1 columns]

# %%
# reutruns pandas series if there is only one colunmn 
pd.read_csv("COVID19_line_list_data.csv", usecols =["country"], squeeze = True)
# Out:
# 0             China
# 1             China
# 2             China
# 3             China
# 4             China
#            ...
# 1080        Austria
# 1081    Afghanistan
# 1082        Algeria
# 1083        Croatia
# 1084    Switzerland
# Name: country, Length: 1085, dtype: object

# %%
# skips the passed rows in new series 
pd.read_csv("COVID19_line_list_data.csv", skiprows = [1,2,3,4,5,6,7,8,9])
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0       10              NaN      1/21/2020         NaN
# 1       11              NaN      1/21/2020         NaN
# 2       12              NaN      1/21/2020         NaN
# 3       13              NaN      1/21/2020         NaN
# 4       14              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1071  1081              2.0      2/25/2020         NaN
# 1072  1082              1.0      2/24/2020         NaN
# 1073  1083              1.0      2/26/2020         NaN
# 1074  1084              1.0      2/25/2020         NaN
# 1075  1085              1.0      2/25/2020         NaN
#
#                                                 summary     location  \
# 0     new confirmed imported COVID-19 pneumonia pati...      Beijing
# 1     new confirmed imported COVID-19 pneumonia pati...      Beijing
# 2     new confirmed imported COVID-19 pneumonia pati...      Beijing
# ...
