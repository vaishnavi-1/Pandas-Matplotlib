# %%
#import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("sales_train.csv" )
df = data.head(20000)

# %%
df
# Out:
#              date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0      02.01.2013               0       59    22154      999.00           1.0
# 1      03.01.2013               0       25     2552      899.00           1.0
# 2      05.01.2013               0       25     2552      899.00          -1.0
# 3      06.01.2013               0       25     2554     1709.05           1.0
# 4      15.01.2013               0       25     2555     1099.00           1.0
# ...           ...             ...      ...      ...         ...           ...
# 19995  20.01.2013               0       29     9044      299.00           1.0
# 19996  20.01.2013               0       29     8776      349.00           1.0
# 19997  18.01.2013               0       29     8764      399.00           1.0
# 19998  30.01.2013               0       29     9174      299.00           1.0
# 19999  10.01.2013               0       29     8595      149.00           1.0
#
# [20000 rows x 6 columns]

# %% [markdown]
# ## Plot the graphs using different attributes of the dataset

# %%
plt.bar(x = df["shop_id"], height = df["item_id"])
plt.xlabel("Shop id")
plt.ylabel("Item id")
# Out:
# Text(0, 0.5, 'Item id')

# %%
plt.figure(figsize=(7,4))
plt.bar(x=df['shop_id'],height=df['item_price'])
plt.xlabel('Shop id')
plt.ylabel('Item Price')
# Out:
# Text(0, 0.5, 'Item Price')

# %%
x = df.shop_id
y = df.item_id
plt.scatter(x,y)
plt.show()

# %%
x = df.shop_id
y = df.item_price
plt.scatter(x,y)
plt.show()

# %%
pt = sns.histplot(df['item_id'])

# %%
at = sns.histplot(df['shop_id'])

# %%
df.boxplot(by ='shop_id', column =['item_id'], grid = False)
# Out:
# <AxesSubplot:title={'center':'item_id'}, xlabel='shop_id'>

# %%
df.boxplot(by ='shop_id', column =['item_price'], grid = False)
# Out:
# <AxesSubplot:title={'center':'item_price'}, xlabel='shop_id'>

# %% [markdown]
# ## Plot the Heatmap

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.heatmap(df.corr(), center=0, cmap='BuGn')
ax.set_title('Heatmap')
# Out:
# Text(0.5, 1.0, 'Heatmap')

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(df.corr(), center=0, cmap='Accent_r', annot=True)
# Out:
# <AxesSubplot:>
